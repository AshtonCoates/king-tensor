# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('cr1.png')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# ## Cropping out UI elements

# %%
arena_start = 140
arena_end = 840
arena = img_rgb[arena_start:arena_end, :]
plt.imshow(arena)
plt.show()
